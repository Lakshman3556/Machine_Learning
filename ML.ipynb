# %% [markdown]
# <a href="https://colab.research.google.com/github/Lakshman3556/Machine_Learning/blob/main/ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data={
    2014:[100.5,150.8,200.9,30000,40000],
    2015:[12000,18000,22000,30000,45000],
    2016:[20000,50000,70000,100000,120000],
    2017:[50000,60000,70000,80000,90000]
}
df=pd.DataFrame(data,index=['Madhu','Kusum','Kinshuk','Ankit','Shruthi'])
print(df)
# Out:
#             2014   2015    2016   2017
# Madhu      100.5  12000   20000  50000
# Kusum      150.8  18000   50000  60000
# Kinshuk    200.9  22000   70000  70000
# Ankit    30000.0  30000  100000  80000
# Shruthi  40000.0  45000  120000  90000

# %%
df.index.tolist()
# Out:
# ['Madhu', 'Kusum', 'Kinshuk', 'Ankit', 'Shruthi']

# %%
df.columns
# Out:
# Index([2014, 2015, 2016, 2017], dtype='int64')

# %%
print(df.info())
print(df.dtypes)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, Madhu to Shruthi
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   2014    5 non-null      float64
#  1   2015    5 non-null      int64
#  2   2016    5 non-null      int64
#  3   2017    5 non-null      int64
# dtypes: float64(1), int64(3)
# memory usage: 372.0+ bytes
# None
# 2014    float64
# 2015      int64
# 2016      int64
# 2017      int64
# dtype: object

# %%
df.shape
# Out:
# (5, 4)

# %%
df.size
# Out:
# 20

# %%
df.ndim
# Out:
# 2

# %%
df.iloc[:,:2]
# Out:
#             2014   2015
# Madhu      100.5  12000
# Kusum      150.8  18000
# Kinshuk    200.9  22000
# Ankit    30000.0  30000
# Shruthi  40000.0  45000

# %%
df.iloc[-2:,:]
# Out:
#             2014   2015    2016   2017
# Ankit    30000.0  30000  100000  80000
# Shruthi  40000.0  45000  120000  90000

# %%
data={
    2018:[160000,110000,500000,340000,900000]
}
df2=pd.DataFrame(data,index=['Madhu','Kusum','Kinshuk','Ankit','Shruthi'])
print(df2)
# Out:
#            2018
# Madhu    160000
# Kusum    110000
# Kinshuk  500000
# Ankit    340000
# Shruthi  900000

# %%
df2.empty
# Out:
# False

# %%
pd.concat([df,df2],axis=1)
# Out:
#             2014   2015    2016   2017    2018
# Madhu      100.5  12000   20000  50000  160000
# Kusum      150.8  18000   50000  60000  110000
# Kinshuk    200.9  22000   70000  70000  500000
# Ankit    30000.0  30000  100000  80000  340000
# Shruthi  40000.0  45000  120000  90000  900000
